# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("Reestr CSV").getOrCreate()

df = spark.read.csv(
    "reestrtz01.01.2026.csv",
    header=True,
    inferSchema=True,
    sep=";"   
)   

df.show(20, truncate=False)
# Out:
# +------+---------------+---------+----------------------------------------------------------------------------------------------+--------+--------+--------------------+-------------+----------------+-----------------+---------+-------+--------+------------+---------+------------------+--------+----------+------------+---------+
# |PERSON|REG_ADDR_KOATUU|OPER_CODE|OPER_NAME                                                                                     |D_REG   |DEP_CODE|DEP                 |BRAND        |MODEL           |VIN              |MAKE_YEAR|COLOR  |KIND    |BODY        |PURPOSE  |FUEL              |CAPACITY|OWN_WEIGHT|TOTAL_WEIGHT|N_REG_NEW|
# +------+---------------+---------+----------------------------------------------------------------------------------------------+--------+--------+--------------------+-------------+----------------+-----------------+---------+-------+--------+------------+---------+------------------+--------+----------+------------+---------+
# |P     |5610100000     |502      |СКАСУВАННЯ ПЕРЕРЕЄСТРАЦІЇ (ПЕРЕРЕЄСТРАЦІЯ НА ПОПЕРЕДНЬОГО ВЛАСНИКА)                           |01.01.26|12235   |ТСЦ 0741            |RENAULT      |SCENIC          |VF1JM0UD631760738|2004     |СІРИЙ  |ЛЕГКОВИЙ|УНІВЕРСАЛ   |ЗАГАЛЬНИЙ|БЕНЗИН АБО ГАЗ    |1998    |1627      |2180        |ВК7858ІС |
# |P     |6325456200     |315      |ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВ. ВЛАСН. ПО ДОГОВОРУ УКЛАДЕНОМУ В ТСЦ                                 |01.01.26|12361   |ТСЦ 6347            |OPEL         |ZAFIRA          |W0L0TGF75X2256914|1999     |СИНІЙ  |ЛЕГКОВИЙ|УНІВЕРСАЛ   |ЗАГАЛЬНИЙ|БЕНЗИН            |1796    |1395      |1960        |АХ9456НК |
# |P     |1810100000     |100      |ПЕРВИННА РЕЄСТРАЦIЯ Б/В ТЗ ПРИДБАНОГО В ТОРГОВЕЛЬНІЙ ОРГАНІЗАЦІЇ, ЯКИЙ ВВЕЗЕНО З-ЗА КОРДОНУ   |01.01.26|13960   |ТСЦ 8048            |NISSAN       |LEAF            |SJNFAAZE0U6023253|2014     |БІЛИЙ  |ЛЕГКОВИЙ|ХЕТЧБЕК     |ЗАГАЛЬНИЙ|ЕЛЕКТРО           |NULL    |1505      |1945        |АА4364YЕ |
# |P     |2120481601     |440      |ПЕРЕРЕЄСТРАЦIЯ ПРИ ВТРАТІ СВIДОЦТВА ПРО РЕЄСТРАЦIЮ                                            |01.01.26|12262   |ТСЦ 2142            |MERCEDES-BENZ|ML 350          |4JGBB86E06A019229|2005     |ЧОРНИЙ |ЛЕГКОВИЙ|УНІВЕРСАЛ   |ЗАГАЛЬНИЙ|БЕНЗИН            |3498    |2135      |2830        |АО1090НІ |
# |P     |2123681301     |105      |ПЕРВИННА РЕЄСТРАЦІЯ НОВОГО ТЗ ПРИДБАНОГО В ТОРГОВЕЛЬНІЙ ОРГАНІЗАЦІЇ, ЯКИЙ ВВЕЗЕНО З-ЗА КОРДОНУ|01.01.26|12292   |ТСЦ 8043            |VDV          |CRF 250         |LRSYCNL3XR0D53096|2024     |БІЛИЙ  |МОТОЦИКЛ|МОТОЦИКЛ    |ЗАГАЛЬНИЙ|БЕНЗИН            |250     |159       |330         |АА3804JВ |
# |P     |7121286401     |254      |НАЛЕЖНИЙ КОРИСТУВАЧ. РЕЄСТРАЦІЯ                                                               |01.01.26|10000   |OLD_ДДАІ МВС УКРАЇНИ|TOYOTA       |RAV4            |JTMBB31V606063941|2007     |СІРИЙ  |ЛЕГКОВИЙ|УНІВЕРСАЛ   |ЗАГАЛЬНИЙ
ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВ. ВЛАСН. ПО ДОГОВОРУ УКЛАДЕНОМУ В ТСЦ                                 |01.01.26|12318   |ТСЦ 4844            |MITSUBISHI   |PAJERO          |JMYLRV73W6J703370|2006     |ЧОРНИЙ |ЛЕГКОВИЙ|УНІВЕРСАЛ   |ЗАГАЛЬНИЙ|БЕНЗИН АБО ГАЗ    |2972    |1952      |2365        |ВЕ6429НН |
# |P     |7410400000     |315      |ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВ. ВЛАСН. ПО ДОГОВОРУ УКЛАДЕНОМУ В ТСЦ                                 |01.01.26|12385   |ТСЦ 7443            |SKODA        |OCTAVIA         |TMBDX41U4A8830411|2009     |СИНІЙ  |ЛЕГКОВИЙ|ХЕТЧБЕК     |ЗАГАЛЬНИЙ|БЕНЗИН АБО ГАЗ    |1595    |1185      |1790        |СЕ0354ЕО |
# |P     |6821810101     |254      |НАЛЕЖНИЙ КОРИСТУВАЧ. РЕЄСТРАЦІЯ                                                               |01.01.26|10000   |OLD_ДДАІ МВС УКРАЇНИ|MERCEDES-BENZ|SPRINTER 316 CDI|WDB9076371P136088|2019     |БІЛИЙ  |ЛЕГКОВИЙ|ПАСАЖИРСЬКИЙ|ЗАГАЛЬНИЙ|ДИЗЕЛЬНЕ ПАЛИВО   |2143    |2589      |3500        |ВХ3053НК |
# |P     |5610100000     |254      |НАЛЕЖНИЙ КОРИСТУВАЧ. РЕЄСТРАЦІЯ                                                               |01.01.26|10000   |OLD_ДДАІ МВС УКРАЇНИ|NISSAN       |ROGUE           |5N1AT2MV6FC851090|2015     |ЗЕЛЕНИЙ|ЛЕГКОВИЙ|УНІВЕРСАЛ   |ЗАГАЛЬНИЙ|БЕНЗИН            |2488    |1714      |2122        |ВК7993ІР |
# |P     |3523655100     |254      |НАЛЕЖНИЙ КОРИСТУВАЧ. РЕЄСТРАЦІЯ                                                               |01.01.26|10000   |OLD_ДДАІ МВС УКРАЇНИ|VOLVO        |XC90            |YV1LCL1V1P1960300|2023     |БІЛИЙ  |ЛЕГКОВИЙ|УНІВЕРСАЛ   |ЗАГАЛЬНИЙ|ЕЛЕКТРО АБО БЕНЗИН|1969    |2064      |2640        |КА8590ІК |
# |P     |1414100000     |254      |НАЛЕЖНИЙ КОРИСТУВАЧ. РЕЄСТРАЦІЯ                                                               |01.01.26|10000   |OLD_ДДАІ МВС УКРАЇНИ|RENAULT      |LOGAN           |VF14SRCL459593439|2017     |СІРИЙ  |ЛЕГКОВИЙ|СЕДАН       |ЗАГАЛЬНИЙ|ДИЗЕЛЬНЕ ПАЛИВО   |1461    |1227      |1590        |АН3784КЕ |
# |P     |4610100000     |254      |НАЛЕЖНИЙ КОРИСТУВАЧ. РЕЄСТРАЦІЯ                                                               |01.01.26|10000   |OLD_ДДАІ МВС УКРАЇНИ|MERCEDES-BENZ|EQE 350 4MATIC  |4JGGM1CB5PA021593|2023     |БІЛИЙ  |ЛЕГКОВИЙ|УНІВЕРСАЛ   |ЗАГАЛЬНИЙ|ЕЛЕКТРО           |NULL    |2670      |3065        |ВС3043YD |
# +------+---------------+---------+----------------------------------------------------------------------------------------------+--------+--------+--------------------+-------------+----------------+-----------------+---------+-------+--------+------------+---------+------------------+--------+----------+------------+---------+
# only showing top 20 rows
